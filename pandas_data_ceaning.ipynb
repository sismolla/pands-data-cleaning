# %%
import pandas as pd
# %cd /content/drive/My Drive/all_machine_learning_liberaries
# Out:
# /content/drive/My Drive/all_machine_learning_liberaries

# %%
df = pd.read_csv('Sport car price.csv')
df
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
df.shape
# Out:
# (995, 8)

# %%
df.loc[200:500][['Car Make','Car Model','Year']].head()
# Out:
#       Car Make                      Car Model  Year
# 200  Chevrolet                     Camaro ZL1  2021
# 201      Dodge  Challenger SRT Hellcat Redeye  2022
# 202       Ford                             GT  2022
# 203     Nissan                           370Z  2021
# 204    Porsche                       Panamera  2022

# %%
if any(df[(df['Year'] == 2022) & (df['Car Make'] == 'Chevrolet')]):
    print(df['Engine Size (L)'].head(500).hist())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
df[(df['Year']<2022) | (df['Car Model'])].head(100).plot.line()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Car Make                   0
# Car Model                  0
# Year                       0
# Engine Size (L)            0
# Horsepower                 0
# Torque (lb-ft)             0
# 0-60 MPH Time (seconds)    0
# Price (in USD)             0
# dtype: int64

# %%
df.dropna(inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Car Make                   0
# Car Model                  0
# Year                       0
# Engine Size (L)            0
# Horsepower                 0
# Torque (lb-ft)             0
# 0-60 MPH Time (seconds)    0
# Price (in USD)             0
# dtype: int64

# %%
m = df['Year'].mode()
df['Year'].fillna(m)
# Out:
# 0       2022
# 1       2021
# 2       2022
# 3       2022
# 4       2021
#         ...
# 1002    2022
# 1003    2021
# 1004    2021
# 1005    2021
# 1006    2021
# Name: Year, Length: 995, dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
#           Car Make      Car Model  Year Engine Size (L) Horsepower  \
# 46         Ferrari  SF90 Stradale  2021               4        986
# 71         McLaren         Artura  2022               3        671
# 90           Lotus       Evora GT  2021             3.5        416
# 104        Ferrari  SF90 Stradale  2021               4        986
# 113        Bugatti         Chiron  2021               8       1500
# ...            ...            ...   ...             ...        ...
# 993           Audi           RS 5  2021             2.9        444
# 997      Chevrolet         Camaro  2021             6.2        455
# 1000  Aston Martin        Vantage  2021               4        503
# 1001       Bugatti         Chiron  2021               8       1479
# 1004       McLaren          Senna  2021               4        789
#
#      Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 46              590                     2.5        625,000
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Car Make, Car Model, Year, Engine Size (L), Horsepower, Torque (lb-ft), 0-60 MPH Time (seconds), Price (in USD)]
# Index: []

# %%
df.to_csv('cleaned.csv')

# %%
# Out:
#   File "<ipython-input-106-79a6623aae7d>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
